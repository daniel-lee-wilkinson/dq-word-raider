# %% [raw]
# # Word Raider Game
#
# The user has to get a 5-letter word.
# For each guessed letter, the programme provides feedback as to whether the letter is in the word.

# %%
game_name ="WordRaiderGame"

# read in words per line from words.txt

word_list = []
with open("text.txt") as f:
	for line in f:
		words = f.rstrip()
		word_list.append(words)
